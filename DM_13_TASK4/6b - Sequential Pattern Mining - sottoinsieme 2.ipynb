# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import entropy
plt.style.use('seaborn-white')

# %% [markdown]
# Non sono considerate le sequenze, che rappresentano i clienti, ottenute a partire dall'intero dataset ma solo dei sottoinsiemi di sequenze, questo perché altrimenti l'esecuzione dell'algoritmo è troppo lenta. Il secondo sottoinsieme considerato contiene le sequenze ottenute a partire dal dataset che hanno almeno 4 elementi e non più di 20 elementi.

# %%
# Leggiamo il dataframe dal file csv 'acquisti.csv'
acquisti = pd.read_csv('acquisti.csv', sep=',')
acquisti.drop(columns=['Unnamed: 0'], inplace=True)
acquisti.head(3)
# Out:
#    BasketID           BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0    536365  2010-12-01 08:26:00  2.55       17850  United Kingdom  85123A
# 1    536365  2010-12-01 08:26:00  3.39       17850  United Kingdom   71053
# 2    536365  2010-12-01 08:26:00  2.75       17850  United Kingdom  84406B
#
#                             ProdDescr  Qta  Spending
# 0  WHITE HANGING HEART T-LIGHT HOLDER    6     15.30
# 1                 WHITE METAL LANTERN    6     20.34
# 2      CREAM CUPID HEARTS COAT HANGER    8     22.00

# %%
# Dizionario che contiene per ogni ProdID la descrizione corrispondente
ProID_to_ProdDescr = dict()
for index, row in acquisti.iterrows():
    key = row['ProdID']
    if not key in ProID_to_ProdDescr:
        ProID_to_ProdDescr[row['ProdID']] = row['ProdDescr']

# %%
# Ogni cliente deve essere rappresentato come una sequenza di acquisti, gli attributi che non servono vengono quindi eliminati
acquisti.drop(columns=['Sale', 'ProdDescr', 'Qta', 'Spending', 'CustomerCountry'], inplace=True)

# %%
tmp = acquisti.groupby(['CustomerID', 'BasketID'])['ProdID'].apply(list)
customer_sequences = tmp.groupby('CustomerID').apply(list)
sequences = customer_sequences.tolist()

# %%
print("Numero di sequenze (uguale al numero di clienti):", len(sequences))
# Out:
# Numero di sequenze (uguale al numero di clienti): 4324

# %%
# Sequenze che contengono almeno 4 basket e al massimo 20 basket
subset_of_sequences = []
for lst in sequences:
    if 4 <= len(lst) <= 20:
        subset_of_sequences.append(lst)
len(subset_of_sequences)
# Out:
# 1391

# %%
from gsp import *
results3 = apriori(subset_of_sequences, 60, verbose=False)

# %%
results3
# Out:
# [([['15036']], 101),
#  ([['15056BL']], 73),
#  ([['15056N']], 87),
#  ([['16156S']], 68),
#  ([['16161P']], 105),
#  ([['16161U']], 70),
#  ([['16169E']], 78),
#  ([['17003']], 75),
#  ([['20675']], 81),
#  ([['20676']], 95),
#  ([['20677']], 70),
#  ([['20679']], 70),
#  ([['20682']], 90),
#  ([['20685']], 182),
#  ([['20711']], 85),
#  ([['20712']], 145),
#  ([['20713']], 131),
#  ([['20717']], 94),
#  ([['20718']], 145),
#  ([['20719']], 140),
#  ([['20723']], 139),
#  ([['20724']], 195),
#  ([['20725']], 328),
#  ([['20726']], 235),
#  ([['20727']], 280),
#  ([['20728']], 289),
#  ([['20749']], 115),
#  ([['20750']], 114),
#  ([['20751']], 67),
#  ([['20754']], 87),
#  ([['20914']], 192),
#  ([['20969']], 96),
#  ([['20970']], 83),
#  ([['20971']], 146),
#  ([['20972']], 173),
#  ([['20973']], 114),
#  ([['20974']], 114),
#  ([['20975']], 129),
#  ([['20977']], 60),
#  ([['20978']], 74),
#  ([['20979']], 90),
#  ([['20981']], 85),
#  ([['20982']], 83),
#  ([['20983']], 100),
#  ([['20984']], 77),
#  ([['20992']], 88),
#  ([['20996']], 68),
#  ([['21034']], 212),
#  ([['21035']], 80),
#  ([['21078']], 85),
#  ([['21080']], 236),
#  ([['21086']], 100),
#  ([['21094']], 100),
#  ([['21098']], 65),
#  ([['21108']], 74),
#  ([['21121']], 132),
#  ([['21122']], 117),
#  ([['21124']], 94),
#  ([['21135']], 68),
#  ([['21136']], 126),
#  ([['21137']], 82),
#  ([['21154']], 95),
#  ([['21155']], 116),
#  ([['21156']], 117),
#  ([['21164']], 90),
#  ([['21165']], 100),
#  ([['21166']], 157),
#  ([['21169']], 100),
#  ([['21172']], 129),
#  ([['21174']], 117),
#  ([['21175']], 192),
#  ([['21179']], 78),
#  ([['21181']], 197),
#  ([['21210']], 121),
#  ([['21212']], 349),
#  ([['21213']], 170),
#  ([['21216']], 88),
#  ([['21217']], 99),
#  ([['21218']], 71),
#  ([['21231']], 114),
#  ([['21232']], 161),
#  ([['21238']], 89),
#  ([['21239']], 82),
#  ([['21240']], 84),
#  ([['21242']], 83),
#  ([['21244']], 65),
#  ([['21259']], 76),
#  ([['21314']], 115),
#  ([['21326']], 80),
#  ([['21328']], 73),
#  ([['21329']], 61),
#  ([['21340']], 98),
#  ([['21355']], 62),
#  ([['21380']], 74),
#  ([['21385']], 90),
#  ([['21390']], 69),
#  ([['21411']], 87),
#  ([['21428']], 69),
#  ([['21429']], 79),
#  ([['21430']], 98),
#  ([['21452']], 61),
#  ([['21479']], 151),
#  ([['21481']], 150),
#  ([['21484']], 117),
#  ([['21485']], 202),
#  ([['21497']], 98),
#  ([['21498']], 140),
#  ([['21499']], 107),
#  ([['21500']], 95),
#  ([['21506']], 95),
#  ([['21507']], 90),
#  ([['21508']], 67),
#  ([['21509']], 89),
#  ([['21523']], 108),
#  ([['21524']], 144),
#  ([['21527']], 61),
#  ([['21531']], 81),
#  ([['21533']], 119),
#  ([['21535']], 126),
#  ([['21539']], 73),
#  ([['21558']], 104),
#  ([['21559']], 145),
#  ([['21561']], 72),
#  ([['21592']], 81),
#  ([['21621']], 140),
#  ([['21623']], 70),
#  ([['21668']], 100),
#  ([['21669']], 102),
#  ([['21670']], 101),
#  ([['21671']], 97),
#  ([['21672']], 101),
#  ([['21673']], 100),
#  ([['21703']], 85),
#  ([['21704']], 78),
#  ([['21715']], 62),
#  ([['21716']], 70),
#  ([['21718']], 67),
#  ([['21731']], 152),
#  ([['21733']], 217),
#  ([['21745']], 80),
#  ([['21746']], 75),
#  ([['21754']], 223),
#  ([['21755']], 202),
#  ([['21756']], 101),
#  ([['21770']], 150),
#  ([['21787']], 62),
#  ([['21790']], 228),
#  ([['21791']], 185),
#  ([['21810']], 64),
#  ([['21818']], 65),
#  ([['21829']], 66),
#  ([['21843']], 143),
#  ([['21868']], 101),
#  ([['21870']], 63),
#  ([['21871']], 75),
#  ([['21874']], 71),
#  ([['21876']], 94),
#  ([['21877']], 100),
#  ([['21878']], 73),
#  ([['21888']], 100),
#  ([['21889']], 173),
#  ([['21890']], 70),
#  ([['21891']], 139),
#  ([['21892']], 122),
#  ([['21899']], 73),
#  ([['21900']], 87),
#  ([['21901']], 72),
#  ([['21903']], 66),
#  ([['21907']], 114),
#  ([['21908']], 121),
#  ([['21912']], 100),
#  ([['21914']], 179),
#  ([['21915']], 197),
#  ([['21916']], 97),
#  ([['21917']], 76),
#  ([['21918']], 114),
#  ([['21922']], 61),
#  ([['21928']], 149),
#  ([['21929']], 180),
#  ([['21930']], 135),
#  ([['21931']], 193),
#  ([['21932']], 121),
#  ([['21933']], 121),
#  ([['21935']], 62),
#  ([['21936']], 140),
#  ([['21937']], 91),
#  ([['21955']], 60),
#  ([['21967']], 66),
#  ([['21974']], 81),
#  ([['21975']], 165),
#  ([['21976']], 109),
#  ([['21977']], 218),
#  ([['21980']], 97),
#  ([['21981']], 82),
#  ([['21982']], 105),
#  ([['21984']], 62),
#  ([['21985']], 140),
#  ([['21986']], 60),
#  ([['21989']], 77),
#  ([['21990']], 73),
#  ([['21992']], 80),
#  ([['21993']], 79),
#  ([['22027']], 107),
#  ([['22028']], 76),
#  ([['22029']], 147),
#  ([['22030']], 109),
#  ([['22037']], 106),
#  ([['22045']], 90),
#  ([['22065']], 79),
#  ([['22077']], 212),
#  ([['22079']], 96),
#  ([['22080']], 66),
#  ([['22082']], 121),
#  ([['22083']], 159),
#  ([['22084']], 161),
#  ([['22086']], 313),
#  ([['22087']], 77),
#  ([['22088']], 60),
#  ([['22089']], 69),
#  ([['22090']], 166),
#  ([['22110']], 64),
#  ([['22111']], 239),
#  ([['22112']], 205),
#  ([['22113']], 180),
#  ([['22114']], 176),
#  ([['22115']], 82),
#  ([['22120']], 68),
#  ([['22131']], 62),
#  ([['22138']], 269),
#  ([['22139']], 240),
#  ([['22141']], 161),
#  ([['22142']], 150),
#  ([['22144']], 183),
#  ([['22147']], 163),
#  ([['22148']], 100),
#  ([['22149']], 187),
#  ([['22150']], 149),
#  ([['22151']], 100),
#  ([['22158']], 102),
#  ([['22169']], 93),
#  ([['22170']], 81),
#  ([['22171']], 99),
#  ([['22173']], 124),
#  ([['22178']], 217),
#  ([['22185']], 65),
#  ([['22186']], 66),
#  ([['22187']], 60),
#  ([['22188']], 68),
#  ([['22189']], 149),
#  ([['22191']], 123),
#  ([['22192']], 104),
#  ([['22193']], 121),
#  ([['22195']], 84),
#  ([['22196']], 77),
#  ([['22197']], 201),
#  ([['22208']], 80),
#  ([['22212']], 91),
#  ([['22219']], 94),
#  ([['22241']], 74),
#  ([['22271']], 108),
#  ([['22273']], 109),
#  ([['22274']], 94),
#  ([['22294']], 99),
#  ([['22295']], 89),
#  ([['22296']], 106),
#  ([['22297']], 99),
#  ([['22301']], 65),
#  ([['22302']], 72),
#  ([['22303']], 91),
#  ([['22326']], 155),
#  ([['22327']], 68),
#  ([['22328']], 134),
#  ([['22329']], 60),
#  ([['22331']], 62),
#  ([['22333']], 96),
#  ([['22348']], 86),
#  ([['22352']], 115),
#  ([['22355']], 153),
#  ([['22356']], 138),
#  ([['22367']], 156),
#  ([['22371']], 69),
#  ([['22379']], 110),
#  ([['22380']], 62),
#  ([['22381']], 77),
#  ([['22382']], 293),
#  ([['22383']], 264),
#  ([['22384']], 263),
#  ([['22385']], 165),
#  ([['22386']], 210),
#  ([['22398']], 92),
#  ([['22411']], 210),
#  ([['22413']], 134),
#  ([['22417']], 146),
#  ([['22418']], 104),
#  ([['22423']], 428),
#  ([['22424']], 92),
#  ([['22427']], 160),
#  ([['22429']], 113),
#  ([['22430']], 64),
#  ([['22431']], 94),
#  ([['22432']], 99),
#  ([['22433']], 78),
#  ([['22435']], 89),
#  ([['22436']], 63),
#  ([['22437']], 84),
#  ([['22439']], 64),
#  ([['22440']], 60),
#  ([['22441']], 64),
#  ([['22456']], 108),
#  ([['22457']], 314),
#  ([['22460']], 67),
#  ([['22464']], 108),
#  ([['22465']], 68),
#  ([['22466']], 61),
#  ([['22467']], 140),
#  ([['22469']], 310),
#  ([['22470']], 262),
#  ([['22485']], 79),
#  ([['22487']], 131),
#  ([['22488']], 116),
#  ([['22489']], 123),
#  ([['22491']], 83),
#  ([['22492']], 113),
#  ([['22493']], 65),
#  ([['22499']], 119),
#  ([['22501']], 100),
#  ([['22502']], 91),
#  ([['22505']], 113),
#  ([['22507']], 126),
#  ([['22508']], 97),
#  ([['22530']], 79),
#  ([['22531']], 71),
#  ([['22534']], 97),
#  ([['22537']], 76),
#  ([['22548']], 70),
#  ([['22549']], 118),
#  ([['22550']], 68),
#  ([['22551']], 187),
#  ([['22553']], 156),
#  ([['22554']], 199),
#  ([['22555']], 158),
#  ([['22556']], 164),
#  ([['22557']], 172),
#  ([['22558']], 192),
#  ([['22560']], 116),
#  ([['22561']], 150),
#  ([['22562']], 83),
#  ([['22563']], 87),
#  ([['22564']], 73),
#  ([['22567']], 73),
#  ([['22568']], 139),
#  ([['22569']], 119),
#  ([['22570']], 131),
#  ([['22571']], 85),
#  ([['22572']], 69),
#  ([['22573']], 64),
#  ([['22574']], 75),
#  ([['22577']], 177),
#  ([['22578']], 174),
#  ([['22579']], 120),
#  ([['22580']], 72),
#  ([['22585']], 105),
#  ([['22588']], 67),
#  ([['22595']], 151),
#  ([['22596']], 91),
#  ([['22600']], 66),
#  ([['22601']], 69),
#  ([['22602']], 83),
#  ([['22605']], 94),
#  ([['22607']], 115),
#  ([['22610']], 66),
#  ([['22614']], 79),
#  ([['22616']], 106),
#  ([['22617']], 149),
#  ([['22619']], 129),
#  ([['22620']], 139),
#  ([['22621']], 186),
#  ([['22622']], 76),
#  ([['22623']], 82),
#  ([['22624']], 183),
#  ([['22625']], 161),
#  ([['22626']], 71),
#  ([['22627']], 103),
#  ([['22629']], 184),
#  ([['22630']], 160),
#  ([['22631']], 93),
#  ([['22632']], 138),
#  ([['22633']], 170),
#  ([['22634']], 77),
#  ([['22635']], 62),
#  ([['22636']], 89),
#  ([['22637']], 110),
#  ([['22644']], 75),
#  ([['22645']], 82),
#  ([['22646']], 99),
#  ([['22652']], 148),
#  ([['22654']], 73),
#  ([['22659']], 123),
#  ([['22661']], 110),
#  ([['22662']], 200),
#  ([['22663']], 110),
#  ([['22665']], 81),
#  ([['22666']], 264),
#  ([['22667']], 131),
#  ([['22668']], 101),
#  ([['22669']], 76),
#  ([['22670']], 77),
#  ([['22672']], 72),
#  ([['22690']], 112),
#  ([['22692']], 118),
#  ([['22693']], 100),
#  ([['22694']], 129),
#  ([['22697']], 199),
#  ([['22698']], 170),
#  ([['22699']], 218),
#  ([['22704']], 61),
#  ([['22712']], 91),
#  ([['22714']], 76),
#  ([['22716']], 106),
#  ([['22720']], 319),
#  ([['22721']], 106),
#  ([['22722']], 222),
#  ([['22723']], 93),
#  ([['22725']], 113),
#  ([['22726']], 207),
#  ([['22727']], 240),
#  ([['22728']], 186),
#  ([['22729']], 114),
#  ([['22730']], 157),
#  ([['22733']], 64),
#  ([['22734']], 146),
#  ([['22736']], 72),
#  ([['22737']], 79),
#  ([['22738']], 75),
#  ([['22739']], 89),
#  ([['22745']], 113),
#  ([['22746']], 97),
#  ([['22747']], 65),
#  ([['22748']], 118),
#  ([['22749']], 145),
#  ([['22750']], 139),
#  ([['22751']], 97),
#  ([['22752']], 95),
#  ([['22754']], 68),
#  ([['22755']], 66),
#  ([['22759']], 133),
#  ([['22766']], 156),
#  ([['22767']], 73),
#  ([['22768']], 85),
#  ([['22771']], 97),
#  ([['22776']], 167),
#  ([['22781']], 68),
#  ([['22784']], 107),
#  ([['22791']], 84),
#  ([['22794']], 69),
#  ([['22795']], 103),
#  ([['22796']], 76),
#  ([['22798']], 74),
#  ([['22800']], 67),
#  ([['22801']], 63),
#  ([['22804']], 146),
#  ([['22809']], 74),
#  ([['22816']], 79),
#  ([['22818']], 78),
#  ([['22822']], 65),
#  ([['22834']], 116),
#  ([['22835']], 166),
#  ([['22837']], 76),
#  ([['22840']], 87),
#  ([['22841']], 79),
#  ([['22844']], 94),
#  ([['22845']], 74),
#  ([['22846']], 92),
#  ([['22847']], 120),
#  ([['22851']], 111),
#  ([['22854']], 70),
#  ([['22855']], 90),
#  ([['22858']], 68),
#  ([['22859']], 72),
#  ([['22865']], 219),
#  ([['22866']], 178),
#  ([['22867']], 168),
#  ([['22892']], 70),
#  ([['22895']], 77),
#  ([['22896']], 84),
#  ([['22897']], 71),
#  ([['22898']], 109),
#  ([['22899']], 102),
#  ([['22900']], 106),
#  ([['22904']], 81),
#  ([['22906']], 63),
#  ([['22907']], 195),
#  ([['22908']], 122),
#  ([['22909']], 187),
#  ([['22910']], 256),
#  ([['22914']], 70),
#  ([['22916']], 66),
#  ([['22917']], 69),
#  ([['22918']], 66),
#  ([['22919']], 68),
#  ([['22920']], 69),
#  ([['22925']], 63),
#  ([['22926']], 86),
#  ([['22930']], 69),
#  ([['22937']], 71),
#  ([['22938']], 81),
#  ([['22940']], 121),
#  ([['22941']], 106),
#  ([['22943']], 77),
#  ([['22950']], 76),
#  ([['22951']], 118),
#  ([['22952']], 197),
#  ([['22956']], 71),
#  ([['22957']], 117),
#  ([['22959']], 70),
#  ([['22960']], 277),
#  ([['22961']], 275),
#  ([['22962']], 99),
#  ([['22963']], 92),
#  ([['22964']], 114),
#  ([['22965']], 95),
#  ([['22966']], 215),
#  ([['22967']], 77),
#  ([['22968']], 69),
#  ([['22969']], 226),
#  ([['22970']], 105),
#  ([['22971']], 100),
#  ([['22972']], 84),
#  ([['22974']], 74),
#  ([['22975']], 72),
#  ([['22977']], 67),
#  ([['22978']], 84),
#  ([['22979']], 126),
#  ([['22980']], 108),
#  ([['22982']], 75),
#  ([['22983']], 127),
#  ([['22986']], 66),
#  ([['22988']], 122),
#  ([['22989']], 130),
#  ([['22990']], 64),
#  ([['22991']], 103),
#  ([['22992']], 115),
#  ([['22993']], 245),
#  ([['22996']], 90),
#  ([['22998']], 123),
#  ([['22999']], 61),
#  ([['23000']], 69),
#  ([['23005']], 64),
#  ([['23012']], 84),
#  ([['23013']], 67),
#  ([['23014']], 63),
#  ([['23032']], 68),
#  ([['23035']], 64),
#  ([['23050']], 61),
#  ([['23052']], 79),
#  ([['23053']], 66),
#  ([['23076']], 113),
#  ([['23077']], 115),
#  ([['23078']], 89),
#  ([['23080']], 75),
#  ([['23082']], 113),
#  ([['23083']], 85),
#  ([['23084']], 264),
#  ([['23089']], 62),
#  ([['23091']], 88),
#  ([['23093']], 62),
#  ([['23096']], 60),
#  ([['23100']], 104),
#  ([['23101']], 101),
#  ([['23102']], 72),
#  ([['23103']], 116),
#  ([['23108']], 158),
#  ([['23109']], 101),
#  ([['23110']], 87),
#  ([['23112']], 84),
#  ([['23118']], 89),
#  ([['23126']], 114),
#  ([['23127']], 79),
#  ([['23128']], 68),
#  ([['23129']], 68),
#  ([['23130']], 67),
#  ([['23132']], 62),
#  ([['23144']], 102),
#  ([['23145']], 73),
#  ([['23146']], 85),
#  ([['23147']], 106),
#  ([['23148']], 83),
#  ([['23152']], 67),
#  ([['23154']], 82),
#  ([['23156']], 76),
#  ([['23157']], 63),
#  ([['23158']], 62),
#  ([['23159']], 78),
#  ([['23165']], 88),
#  ([['23166']], 64),
#  ([['23168']], 85),
#  ([['23169']], 104),
#  ([['23170']], 120),
#  ([['23171']], 106),
#  ([['23172']], 94),
#  ([['23173']], 140),
#  ([['23174']], 107),
#  ([['23175']], 117),
#  ([['23176']], 76),
#  ([['23177']], 86),
#  ([['23182']], 81),
#  ([['23184']], 69),
#  ([['23188']], 108),
#  ([['23190']], 94),
#  ([['23191']], 107),
#  ([['23192']], 117),
#  ([['23194']], 60),
#  ([['23196']], 101),
#  ([['23197']], 63),
#  ([['23198']], 143),
#  ([['23199']], 202),
#  ([['23200']], 160),
#  ([['23201']], 221),
#  ([['23202']], 223),
#  ([['23203']], 310),
#  ([['23204']], 122),
#  ([['23205']], 122),
#  ([['23206']], 241),
#  ([['23207']], 236),
#  ([['23208']], 190),
#  ([['23209']], 295),
#  ([['23210']], 61),
#  ([['23215']], 82),
#  ([['23229']], 99),
#  ([['23230']], 102),
#  ([['23231']], 111),
#  ([['23232']], 107),
#  ([['23233']], 77),
#  ([['23234']], 120),
#  ([['23235']], 62),
#  ([['23236']], 115),
#  ([['23237']], 88),
#  ([['23238']], 97),
#  ([['23239']], 68),
#  ([['23240']], 176),
#  ([['23241']], 108),
#  ([['23242']], 79),
#  ([['23243']], 160),
#  ([['23244']], 61),
#  ([['23245']], 273),
#  ([['23247']], 136),
#  ([['23254']], 109),
#  ([['23255']], 65),
#  ([['23256']], 130),
#  ([['23263']], 152),
#  ([['23264']], 106),
#  ([['23265']], 106),
#  ([['23266']], 112),
#  ([['23275']], 99),
#  ([['23283']], 83),
#  ([['23284']], 203),
#  ([['23289']], 62),
#  ([['23290']], 72),
#  ([['23291']], 60),
#  ([['23292']], 70),
#  ([['23293']], 153),
#  ([['23294']], 101),
#  ([['23295']], 120),
#  ([['23296']], 114),
#  ([['23297']], 65),
#  ([['23298']], 333),
#  ([['23299']], 62),
#  ([['23300']], 198),
#  ([['23301']], 214),
#  ([['23302']], 76),
#  ([['23306']], 109),
#  ([['23307']], 206),
#  ([['23308']], 124),
#  ([['23309']], 96),
#  ([['23310']], 81),
#  ([['23311']], 149),
#  ([['23312']], 103),
#  ([['23313']], 145),
#  ([['23318']], 144),
#  ([['23319']], 165),
#  ([['23320']], 136),
#  ([['23321']], 217),
#  ([['23322']], 195),
#  ([['23323']], 116),
#  ([['23328']], 105),
#  ([['23329']], 109),
#  ([['23330']], 82),
#  ([['23332']], 116),
#  ([['23333']], 93),
#  ([['23340']], 62),
#  ([['23343']], 177),
#  ([['23344']], 230),
#  ([['23345']], 60),
#  ([['23349']], 130),
#  ([['23350']], 116),
#  ([['23351']], 149),
#  ([['23352']], 94),
#  ([['23353']], 121),
#  ([['23354']], 133),
#  ([['23355']], 266),
#  ([['23356']], 175),
#  ([['23366']], 61),
#  ([['23367']], 97),
#  ([['23368']], 73),
#  ([['23374']], 62),
#  ([['23378']], 79),
#  ([['23382']], 76),
#  ([['23388']], 65),
#  ([['23389']], 87),
#  ([['23390']], 70),
#  ([['23393']], 88),
#  ([['23395']], 69),
#  ([['23396']], 69),
#  ([['23397']], 79),
#  ([['23399']], 91),
#  ([['23404']], 62),
#  ([['23407']], 66),
#  ([['23426']], 77),
#  ([['23434']], 63),
#  ([['23439']], 155),
#  ([['23480']], 92),
#  ([['23489']], 73),
#  ([['23493']], 155),
#  ([['23494']], 78),
#  ([['23497']], 90),
#  ([['23503']], 163),
#  ([['23504']], 88),
#  ([['23506']], 71),
#  ([['23508']], 61),
#  ([['23534']], 89),
#  ([['23535']], 82),
#  ([['23546']], 64),
#  ([['23569']], 80),
#  ([['23570']], 107),
#  ([['23571']], 113),
#  ([['23581']], 157),
#  ([['23582']], 127),
#  ([['23583']], 157),
#  ([['23681']], 75),
#  ([['35961']], 64),
#  ([['35970']], 142),
#  ([['46000S']], 64),
#  ([['47504K']], 70),
#  ([['47559B']], 86),
#  ([['47566']], 366),
#  ([['47566B']], 115),
#  ([['47590A']], 124),
#  ([['47590B']], 131),
#  ([['47591D']], 137),
#  ([['48111']], 60),
#  ([['48129']], 70),
#  ([['48138']], 177),
#  ([['48184']], 133),
#  ([['48185']], 81),
#  ([['48187']], 162),
#  ([['48188']], 95),
#  ([['48194']], 162),
#  ([['71053']], 77),
#  ([['71459']], 120),
#  ([['71477']], 88),
#  ([['72741']], 82),
#  ([['79321']], 103),
#  ([['82482']], 255),
#  ([['82483']], 153),
#  ([['82484']], 158),
#  ([['82486']], 141),
#  ([['82494L']], 241),
#  ([['82551']], 90),
#  ([['82552']], 109),
#  ([['82578']], 83),
#  ([['82580']], 121),
#  ([['82581']], 107),
#  ([['82582']], 98),
#  ([['82583']], 123),
#  ([['82600']], 115),
#  ([['84029E']], 143),
#  ([['84029G']], 120),
#  ([['84030E']], 113),
#  ([['84050']], 76),
#  ([['84077']], 164),
#  ([['84347']], 105),
#  ([['84375']], 153),
#  ([['84378']], 205),
#  ([['84380']], 184),
#  ([['84406B']], 77),
#  ([['84536A']], 85),
#  ([['84596B']], 102),
#  ([['84596F']], 84),
#  ([['84692']], 124),
#  ([['84755']], 165),
#  ([['84792']], 74),
#  ([['84832']], 78),
#  ([['84836']], 156),
#  ([['84879']], 325),
#  ([['84945']], 96),
#  ([['84946']], 196),
#  ([['84947']], 89),
#  ([['84949']], 83),
#  ([['84970L']], 143),
#  ([['84970S']], 165),
#  ([['84978']], 153),
#  ([['84987']], 102),
#  ([['84988']], 109),
#  ([['84991']], 224),
#  ([['84992']], 182),
#  ([['84997A']], 84),
#  ([['84997B']], 126),
#  ([['84997C']], 122),
#  ([['84997D']], 142),
#  ([['85014A']], 111),
#  ([['85014B']], 124),
#  ([['85048']], 85),
#  ([['85049A']], 111),
#  ([['85049C']], 91),
#  ([['85049E']], 147),
#  ([['85049G']], 97),
#  ([['85053']], 88),
#  ([['85066']], 159),
#  ([['85099B']], 349),
#  ([['85099C']], 166),
#  ([['85099F']], 178),
#  ([['85123A']], 429),
#  ([['85150']], 118),
#  ([['85152']], 148),
#  ([['85184C']], 65),
#  ([['85206A']], 63),
#  ([['20712', '20726']], 68),
#  ([['20712', '22386']], 61),
#  ([['20712', '85099B']], 88),
#  ([['20713', '21931']], 62),
#  ([['20713', '85099B']], 73),
#  ([['20718', '85099B']], 62),
#  ([['20719', '20723']], 69),
#  ([['20719', '20724']], 86),
#  ([['20719', '20726']], 64),
#  ([['20719', '22355']], 73),
#  ([['20719', '22356']], 68),
#  ([['20719', '23204']], 61),
#  ([['20723', '20724']], 88),
#  ([['20723', '20725']], 64),
#  ([['20723', '20728']], 62),
#  ([['20723', '22355']], 76),
#  ([['20723', '22356']], 63),
#  ([['20723', '22383']], 61),
#  ([['20723', '23204']], 61),
#  ([['20723', '85099B']], 63),
#  ([['20724', '20725']], 87),
#  ([['20724', '20727']], 68),
#  ([['20724', '20728']], 63),
#  ([['20724', '22355']], 88),
#  ([['20724', '22356']], 99),
#  ([['20724', '22382']], 68),
#  ([['20724', '22383']], 63),
#  ([['20724', '22384']], 61),
#  ([['20724', '22661']], 60),
#  ([['20724', '23203']], 60),
#  ([['20724', '23204']], 70),
#  ([['20724', '23209']], 63),
#  ([['20724', '85099B']], 92),
#  ([['20725', '20726']], 140),
#  ([['20725', '20727']], 164),
#  ([['20725', '20728']], 167),
#  ([['20725', '21212']], 86),
#  ([['20725', '21929']], 65),
#  ([['20725', '21931']], 80),
#  ([['20725', '21936']], 71),
#  ([['20725', '22355']], 67),
#  ([['20725', '22382']], 153),
#  ([['20725', '22383']], 163),
#  ([['20725', '22384']], 159),
#  ([['20725', '22385']], 63),
#  ([['20725', '22386']], 84),
#  ([['20725', '22411']], 64),
#  ([['20725', '22662']], 116),
#  ([['20725', '23199']], 75),
#  ([['20725', '23201']], 64),
#  ([['20725', '23202']], 70),
#  ([['20725', '23203']], 105),
#  ([['20725', '23206']], 124),
#  ([['20725', '23207']], 115),
#  ([['20725', '23208']], 99),
#  ([['20725', '23209']], 150),
#  ([['20725', '23298']], 67),
#  ([['20725', '47566']], 68),
#  ([['20725', '85099B']], 139),
#  ([['20725', '85099C']], 64),
#  ([['20725', '85099F']], 63),
#  ([['20725', '85123A']], 81),
#  ([['20726', '20727']], 124),
#  ([['20726', '20728']], 126),
#  ([['20726', '22326']], 69),
#  ([['20726', '22382']], 146),
#  ([['20726', '22383']], 126),
#  ([['20726', '22384']], 116),
#  ([['20726', '22662']], 92),
#  ([['20726', '23199']], 64),
#  ([['20726', '23203']], 67),
#  ([['20726', '23206']], 107),
#  ([['20726', '23207']], 85),
#  ([['20726', '23208']], 75),
#  ([['20726', '23209']], 105),
#  ([['20726', '85099B']], 74),
#  ([['20727', '20728']], 137),
#  ([['20727', '21212']], 60),
#  ([['20727', '21930']], 68),
#  ([['20727', '21931']], 70),
#  ([['20727', '22382']], 140),
#  ([['20727', '22383']], 153),
#  ([['20727', '22384']], 152),
#  ([['20727', '22386']], 66),
#  ([['20727', '22662']], 106),
#  ([['20727', '23199']], 70),
#  ([['20727', '23201']], 64),
#  ([['20727', '23202']], 61),
#  ([['20727', '23203']], 86),
#  ([['20727', '23206']], 121),
#  ([['20727', '23207']], 108),
#  ([['20727', '23208']], 98),
#  ([['20727', '23209']], 136),
#  ([['20727', '85099B']], 93),
#  ([['20727', '85123A']], 75),
#  ([['20728', '21931']], 69),
#  ([['20728', '22382']], 142),
#  ([['20728', '22383']], 163),
#  ([['20728', '22384']], 151),
#  ([['20728', '22386']], 65),
#  ([['20728', '22662']], 97),
#  ([['20728', '23199']], 68),
#  ([['20728', '23201']], 66),
#  ([['20728', '23203']], 78),
#  ([['20728', '23206']], 106),
#  ([['20728', '23207']], 101),
#  ([['20728', '23208']], 83),
#  ([['20728', '23209']], 117),
#  ([['20728', '85099B']], 95),
#  ([['20728', '85123A']], 81),
#  ([['20971', '20972']], 83),
#  ([['21034', '85123A']], 64),
#  ([['21080', '21086']], 77),
#  ([['21080', '21094']], 79),
#  ([['21080', '21212']], 82),
#  ([['21086', '21094']], 90),
#  ([['21121', '21122']], 70),
#  ([['21121', '21124']], 62),
#  ([['21122', '21124']], 81),
#  ([['21136', '84879']], 86),
#  ([['21156', '22367']], 68),
#  ([['21166', '21175']], 100),
#  ([['21166', '21181']], 86),
#  ([['21166', '85152']], 91),
#  ([['21175', '21181']], 91),
#  ([['21175', '21908']], 64),
#  ([['21175', '22413']], 67),
#  ([['21175', '82600']], 61),
#  ([['21175', '85152']], 82),
#  ([['21181', '82600']], 62),
#  ([['21181', '85123A']], 65),
#  ([['21181', '85150']], 70),
#  ([['21181', '85152']], 80),
#  ([['21210', '21212']], 62),
#  ([['21212', '21213']], 100),
#  ([['21212', '21975']], 97),
#  ([['21212', '21976']], 67),
#  ([['21212', '21977']], 138),
#  ([['21212', '22383']], 63),
#  ([['21212', '22417']], 83),
#  ([['21212', '22423']], 64),
#  ([['21212', '22951']], 68),
#  ([['21212', '22960']], 70),
#  ([['21212', '22961']], 61),
#  ([['21212', '22993']], 60),
#  ([['21212', '23307']], 79),
#  ([['21212', '84991']], 129),
#  ([['21212', '84992']], 91),
#  ([['21212', '85099B']], 70),
#  ([['21212', '85123A']], 64),
#  ([['21213', '21975']], 64),
#  ([['21213', '21977']], 62),
#  ([['21213', '84991']], 69),
#  ([['21231', '21232']], 77),
#  ([['21239', '21240']], 61),
#  ([['21485', '22111']], 100),
#  ([['21485', '22112']], 83),
#  ([['21485', '22113']], 64),
#  ([['21499', '21500']], 63),
#  ([['21533', '21535']], 65),
#  ([['21558', '21559']], 72),
#  ([['21559', '22352']], 62),
#  ([['21668', '21669']], 75),
#  ([['21668', '21670']], 71),
#  ([['21668', '21671']], 69),
#  ([['21668', '21672']], 71),
#  ([['21668', '21673']], 63),
#  ([['21669', '21670']], 66),
#  ([['21669', '21671']], 65),
#  ([['21669', '21672']], 63),
#  ([['21669', '21673']], 65),
#  ([['21670', '21671']], 71),
#  ([['21670', '21672']], 66),
#  ([['21670', '21673']], 67),
#  ...]

# %%
len(results3)
# Out:
# 5004

# %%
# Sottosequenze che contengono 4 elementi e hanno support più alto
seq_l4 = []

for t in results3:
    lst, support = t
    if len(lst) == 4 and support > 66 :
        seq_l4.append((lst, support))

# %%
len(seq_l4)
# Out:
# 6

# %%
seq_l4
# Out:
# [([['84879'], ['84879'], ['84879'], ['84879']], 67),
#  ([['85099B'], ['23203'], ['23203'], ['23203']], 67),
#  ([['85099B'], ['23203'], ['85099B'], ['23203']], 68),
#  ([['85099B'], ['85099B'], ['23203'], ['85099B']], 69),
#  ([['85099B'], ['85099B'], ['85099B'], ['85099B']], 83),
#  ([['85123A'], ['85123A'], ['85123A'], ['85123A']], 107)]

# %%
for seq in seq_l4:
    lst, sup = seq
    for l in lst:
        for item in l:
            print(item + ": " + ProID_to_ProdDescr[item])
    print("support " + str(sup))
    print("\n")
# Out:
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# support 67
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 67
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# support 68
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# support 69
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 83
#
#
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# support 107

# %%
seq_l3_1 = []
seq_l3_2 = []
for t in results3:
    lst, support = t
    if len(lst) == 3:
        if (len(lst[0]) > 1 or len(lst[1]) > 1 or len(lst[2]) > 1) and support == 63:
            seq_l3_1.append((lst, support))
        elif len(lst[0]) == 1 and len(lst[1]) == 1 and len(lst[2]) == 1 and support > 90:
            seq_l3_2.append((lst, support))

# %%
len(seq_l3_1)
# Out:
# 18

# %%
# la variabile seq_l3_1 contiene sottosequenze che hanno 3 elementi e più di 3 oggetti
seq_l3_1
# Out:
# [([['20725', '20727'], ['20728'], ['20727']], 63),
#  ([['20725', '20727'], ['22383'], ['20727']], 63),
#  ([['20725', '20728'], ['20728'], ['20725']], 63),
#  ([['20725', '20728'], ['22383'], ['22383']], 63),
#  ([['20725', '20728'], ['23209'], ['23209']], 63),
#  ([['20725', '22383'], ['20725'], ['22383']], 63),
#  ([['20725', '22383'], ['20728'], ['20725']], 63),
#  ([['20725', '22383'], ['23209'], ['20725']], 63),
#  ([['20725', '22383'], ['23209'], ['23209']], 63),
#  ([['20725', '22384'], ['22384'], ['20725']], 63),
#  ([['20725', '22384'], ['22384'], ['20727']], 63),
#  ([['20727', '22383'], ['20727'], ['20725']], 63),
#  ([['20727', '22383'], ['22383'], ['20725']], 63),
#  ([['20727', '22383'], ['23209'], ['20727']], 63),
#  ([['20727', '22384'], ['20725'], ['20725']], 63),
#  ([['20728', '22383'], ['20725'], ['22383']], 63),
#  ([['20728', '22383'], ['22383'], ['22384']], 63),
#  ([['23203', '85099B'], ['23203'], ['85099B']], 63)]

# %%
for seq in seq_l3_1:
    lst, sup = seq
    for l in lst:
        for item in l:
            print(item + ": " + ProID_to_ProdDescr[item])
    print("support " + str(sup))
    print("\n")
# Out:
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20728: LUNCH BAG CARS BLUE
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22384: LUNCH BAG PINK POLKADOT
# support 63
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# support 63

# %%
# la variabile seq_l3_2 contiene sottosequenze che hanno 3 elementi e 3 oggetti
seq_l3_2
# Out:
# [([['20725'], ['20725'], ['20725']], 122),
#  ([['20725'], ['20725'], ['20727']], 106),
#  ([['20725'], ['20725'], ['23209']], 99),
#  ([['20725'], ['20727'], ['20725']], 99),
#  ([['20725'], ['20727'], ['20727']], 94),
#  ([['20725'], ['22383'], ['20725']], 93),
#  ([['20725'], ['22384'], ['20727']], 92),
#  ([['20725'], ['23209'], ['20725']], 98),
#  ([['20725'], ['23209'], ['23209']], 95),
#  ([['20727'], ['20725'], ['20727']], 99),
#  ([['20727'], ['20727'], ['20725']], 92),
#  ([['20727'], ['20727'], ['20727']], 95),
#  ([['20728'], ['22383'], ['22383']], 91),
#  ([['22383'], ['22383'], ['20725']], 91),
#  ([['22383'], ['22383'], ['22383']], 103),
#  ([['22423'], ['22423'], ['22423']], 117),
#  ([['23203'], ['23203'], ['23203']], 98),
#  ([['23209'], ['23209'], ['23209']], 93),
#  ([['47566'], ['47566'], ['47566']], 99),
#  ([['84879'], ['84879'], ['84879']], 127),
#  ([['85099B'], ['20725'], ['85099B']], 100),
#  ([['85099B'], ['23203'], ['23203']], 113),
#  ([['85099B'], ['23203'], ['85099B']], 118),
#  ([['85099B'], ['85099B'], ['23203']], 113),
#  ([['85099B'], ['85099B'], ['85099B']], 131),
#  ([['85123A'], ['85123A'], ['85123A']], 172)]

# %%
for seq in seq_l3_2:
    lst, sup = seq
    for l in lst:
        for item in l:
            print(item + ": " + ProID_to_ProdDescr[item])
    print("support " + str(sup))
    print("\n")
# Out:
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 122
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 106
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# 23209: LUNCH BAG DOILEY PATTERN
# support 99
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 99
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 94
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 93
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 92
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 23209: LUNCH BAG DOILEY PATTERN
# 20725: LUNCH BAG RED RETROSPOT
# support 98
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 95
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 99
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 92
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 95
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 91
#
#
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 91
#
#
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 103
#
#
# 22423: REGENCY CAKESTAND 3 TIER
# 22423: REGENCY CAKESTAND 3 TIER
# 22423: REGENCY CAKESTAND 3 TIER
# support 117
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 98
#
#
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 93
#
#
# 47566: PARTY BUNTING
# 47566: PARTY BUNTING
# 47566: PARTY BUNTING
# support 99
#
#
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# 84879: ASSORTED COLOUR BIRD ORNAMENT
# support 127
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 100
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 113
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# support 118
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# support 113
#
#
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 131
#
#
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# support 172

# %%
seq_l3_3 = []
for t in results3:
    lst, support = t
    if len(lst) == 3:
        if (len(lst[0]) > 1 or len(lst[1]) > 1 or len(lst[2]) > 1):
            seq_l3_3.append((lst, support))

# %%
# la variabile seq_l3_3 contiene tutte le sottosequenze che hanno 3 elementi e più di 3 oggetti
seq_l3_3
# Out:
# [([['20725', '20727'], ['20725'], ['20725']], 68),
#  ([['20725', '20727'], ['20725'], ['20727']], 78),
#  ([['20725', '20727'], ['20725'], ['22384']], 61),
#  ([['20725', '20727'], ['20725'], ['23209']], 60),
#  ([['20725', '20727'], ['20727'], ['20725']], 70),
#  ([['20725', '20727'], ['20727'], ['20727']], 72),
#  ([['20725', '20727'], ['20727'], ['22384']], 60),
#  ([['20725', '20727'], ['20728'], ['20725']], 62),
#  ([['20725', '20727'], ['20728'], ['20727']], 63),
#  ([['20725', '20727'], ['22383'], ['20727']], 63),
#  ([['20725', '20727'], ['22384'], ['20725']], 61),
#  ([['20725', '20727'], ['22384'], ['20727']], 69),
#  ([['20725', '20727'], ['23206'], ['20727']], 60),
#  ([['20725', '20727'], ['23209'], ['20727']], 64),
#  ([['20725', '20727'], ['23209'], ['23209']], 61),
#  ([['20725', '20728'], ['20725'], ['20725']], 66),
#  ([['20725', '20728'], ['20725'], ['20727']], 64),
#  ([['20725', '20728'], ['20728'], ['20725']], 63),
#  ([['20725', '20728'], ['22383'], ['20725']], 64),
#  ([['20725', '20728'], ['22383'], ['22383']], 63),
#  ([['20725', '20728'], ['22384'], ['20727']], 62),
#  ([['20725', '20728'], ['23209'], ['20725']], 60),
#  ([['20725', '20728'], ['23209'], ['23209']], 63),
#  ([['20725', '22382'], ['20725'], ['22382']], 62),
#  ([['20725', '22383'], ['20725'], ['20725']], 69),
#  ([['20725', '22383'], ['20725'], ['20727']], 64),
#  ([['20725', '22383'], ['20725'], ['22383']], 63),
#  ([['20725', '22383'], ['20727'], ['20725']], 60),
#  ([['20725', '22383'], ['20727'], ['20727']], 61),
#  ([['20725', '22383'], ['20728'], ['20725']], 63),
#  ([['20725', '22383'], ['22383'], ['20725']], 73),
#  ([['20725', '22383'], ['22383'], ['20727']], 67),
#  ([['20725', '22383'], ['22383'], ['22383']], 68),
#  ([['20725', '22383'], ['23209'], ['20725']], 63),
#  ([['20725', '22383'], ['23209'], ['22383']], 60),
#  ([['20725', '22383'], ['23209'], ['23209']], 63),
#  ([['20725', '22384'], ['20725'], ['20725']], 66),
#  ([['20725', '22384'], ['20725'], ['20727']], 65),
#  ([['20725', '22384'], ['20725'], ['22384']], 62),
#  ([['20725', '22384'], ['20727'], ['20725']], 62),
#  ([['20725', '22384'], ['22384'], ['20725']], 63),
#  ([['20725', '22384'], ['22384'], ['20727']], 63),
#  ([['20725', '22384'], ['22384'], ['22384']], 60),
#  ([['20727', '20728'], ['22383'], ['20727']], 60),
#  ([['20727', '20728'], ['22384'], ['20727']], 60),
#  ([['20727', '22383'], ['20725'], ['20727']], 64),
#  ([['20727', '22383'], ['20727'], ['20725']], 63),
#  ([['20727', '22383'], ['20727'], ['20727']], 66),
#  ([['20727', '22383'], ['20727'], ['22383']], 61),
#  ([['20727', '22383'], ['22383'], ['20725']], 63),
#  ([['20727', '22383'], ['22383'], ['20727']], 70),
#  ([['20727', '22383'], ['22383'], ['22383']], 66),
#  ([['20727', '22383'], ['22384'], ['20727']], 61),
#  ([['20727', '22383'], ['23206'], ['20727']], 60),
#  ([['20727', '22383'], ['23209'], ['20727']], 63),
#  ([['20727', '22384'], ['20725'], ['20725']], 63),
#  ([['20727', '22384'], ['20725'], ['20727']], 69),
#  ([['20727', '22384'], ['20727'], ['20725']], 65),
#  ([['20727', '22384'], ['20727'], ['20727']], 65),
#  ([['20727', '22384'], ['20727'], ['22384']], 60),
#  ([['20727', '22384'], ['22384'], ['20725']], 61),
#  ([['20727', '22384'], ['22384'], ['20727']], 66),
#  ([['20728', '22383'], ['20725'], ['20725']], 65),
#  ([['20728', '22383'], ['20725'], ['20727']], 60),
#  ([['20728', '22383'], ['20725'], ['22383']], 63),
#  ([['20728', '22383'], ['22383'], ['20725']], 67),
#  ([['20728', '22383'], ['22383'], ['20727']], 66),
#  ([['20728', '22383'], ['22383'], ['20728']], 60),
#  ([['20728', '22383'], ['22383'], ['22383']], 74),
#  ([['20728', '22383'], ['22383'], ['22384']], 63),
#  ([['20728', '22383'], ['23209'], ['22383']], 61),
#  ([['20728', '22384'], ['20725'], ['22383']], 60),
#  ([['21733', '85123A'], ['85123A'], ['85123A']], 64),
#  ([['22386', '85099B'], ['22386'], ['85099B']], 66),
#  ([['22386', '85099B'], ['23203'], ['85099B']], 62),
#  ([['22386', '85099B'], ['85099B'], ['22386']], 60),
#  ([['22386', '85099B'], ['85099B'], ['85099B']], 75),
#  ([['22411', '85099B'], ['85099B'], ['23203']], 60),
#  ([['22411', '85099B'], ['85099B'], ['85099B']], 61),
#  ([['22469', '22470'], ['85123A'], ['85123A']], 61),
#  ([['22726', '22727'], ['22726'], ['22726']], 70),
#  ([['22726', '22727'], ['22726'], ['22727']], 67),
#  ([['22726', '22727'], ['22727'], ['22726']], 67),
#  ([['22726', '22727'], ['22727'], ['22727']], 65),
#  ([['23202', '23203'], ['23203'], ['23203']], 60),
#  ([['23203', '23209'], ['23203'], ['23203']], 60),
#  ([['23203', '85099B'], ['23203'], ['23203']], 65),
#  ([['23203', '85099B'], ['23203'], ['85099B']], 63),
#  ([['23203', '85099B'], ['85099B'], ['23203']], 60),
#  ([['82482', '82494L'], ['82482'], ['82494L']], 62)]

# %%
for seq in seq_l3_3:
    lst, sup = seq
    for l in lst:
        for item in l:
            print(item + ": " + ProID_to_ProdDescr[item])
    print("support " + str(sup))
    print("\n")
# Out:
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 68
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 78
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# support 61
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# 23209: LUNCH BAG DOILEY PATTERN
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 70
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 72
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# support 62
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20728: LUNCH BAG CARS BLUE
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# support 61
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 69
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 23206: LUNCH BAG APPLE DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 23209: LUNCH BAG DOILEY PATTERN
# 20727: LUNCH BAG  BLACK SKULL.
# support 64
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 61
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 66
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 64
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 64
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 62
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 23209: LUNCH BAG DOILEY PATTERN
# 20725: LUNCH BAG RED RETROSPOT
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 20728: LUNCH BAG CARS BLUE
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22382: LUNCH BAG SPACEBOY DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 22382: LUNCH BAG SPACEBOY DESIGN
# support 62
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 69
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 64
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 61
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 20728: LUNCH BAG CARS BLUE
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 73
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 67
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 68
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 22383: LUNCH BAG SUKI  DESIGN
# support 60
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 23209: LUNCH BAG DOILEY PATTERN
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 66
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 65
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# support 62
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 62
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20725: LUNCH BAG RED RETROSPOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# support 60
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 60
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 20728: LUNCH BAG CARS BLUE
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 60
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 64
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 66
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# support 61
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 70
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 66
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 61
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 23206: LUNCH BAG APPLE DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 60
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 20727: LUNCH BAG  BLACK SKULL.
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 63
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 69
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20725: LUNCH BAG RED RETROSPOT
# support 65
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# 20727: LUNCH BAG  BLACK SKULL.
# support 65
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# support 60
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# support 61
#
#
# 20727: LUNCH BAG  BLACK SKULL.
# 22384: LUNCH BAG PINK POLKADOT
# 22384: LUNCH BAG PINK POLKADOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 66
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 20725: LUNCH BAG RED RETROSPOT
# support 65
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 20727: LUNCH BAG  BLACK SKULL.
# support 60
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# support 63
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20725: LUNCH BAG RED RETROSPOT
# support 67
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20727: LUNCH BAG  BLACK SKULL.
# support 66
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 20728: LUNCH BAG CARS BLUE
# support 60
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# support 74
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 22383: LUNCH BAG SUKI  DESIGN
# 22384: LUNCH BAG PINK POLKADOT
# support 63
#
#
# 20728: LUNCH BAG CARS BLUE
# 22383: LUNCH BAG SUKI  DESIGN
# 23209: LUNCH BAG DOILEY PATTERN
# 22383: LUNCH BAG SUKI  DESIGN
# support 61
#
#
# 20728: LUNCH BAG CARS BLUE
# 22384: LUNCH BAG PINK POLKADOT
# 20725: LUNCH BAG RED RETROSPOT
# 22383: LUNCH BAG SUKI  DESIGN
# support 60
#
#
# 21733: RED HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# support 64
#
#
# 22386: JUMBO BAG PINK POLKADOT
# 85099B: JUMBO BAG RED RETROSPOT
# 22386: JUMBO BAG PINK POLKADOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 66
#
#
# 22386: JUMBO BAG PINK POLKADOT
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# support 62
#
#
# 22386: JUMBO BAG PINK POLKADOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 22386: JUMBO BAG PINK POLKADOT
# support 60
#
#
# 22386: JUMBO BAG PINK POLKADOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 75
#
#
# 22411: JUMBO SHOPPER VINTAGE RED PAISLEY
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# support 60
#
#
# 22411: JUMBO SHOPPER VINTAGE RED PAISLEY
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# support 61
#
#
# 22469: HEART OF WICKER SMALL
# 22470: HEART OF WICKER LARGE
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# 85123A: WHITE HANGING HEART T-LIGHT HOLDER
# support 61
#
#
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22727: ALARM CLOCK BAKELIKE RED
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22726: ALARM CLOCK BAKELIKE GREEN
# support 70
#
#
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22727: ALARM CLOCK BAKELIKE RED
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22727: ALARM CLOCK BAKELIKE RED
# support 67
#
#
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22727: ALARM CLOCK BAKELIKE RED
# 22727: ALARM CLOCK BAKELIKE RED
# 22726: ALARM CLOCK BAKELIKE GREEN
# support 67
#
#
# 22726: ALARM CLOCK BAKELIKE GREEN
# 22727: ALARM CLOCK BAKELIKE RED
# 22727: ALARM CLOCK BAKELIKE RED
# 22727: ALARM CLOCK BAKELIKE RED
# support 65
#
#
# 23202: JUMBO BAG VINTAGE LEAF
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 60
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 23209: LUNCH BAG DOILEY PATTERN
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 60
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 23203: JUMBO BAG DOILEY PATTERNS
# support 65
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# support 63
#
#
# 23203: JUMBO BAG DOILEY PATTERNS
# 85099B: JUMBO BAG RED RETROSPOT
# 85099B: JUMBO BAG RED RETROSPOT
# 23203: JUMBO BAG DOILEY PATTERNS
# support 60
#
#
# 82482: WOODEN PICTURE FRAME WHITE FINISH
# 82494L: WOODEN FRAME ANTIQUE WHITE
# 82482: WOODEN PICTURE FRAME WHITE FINISH
# 82494L: WOODEN FRAME ANTIQUE WHITE
# support 62
